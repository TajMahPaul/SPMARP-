# %%
from db.data import Data
import gurobipy as gp
from gurobipy import GRB

import pandas as pd

# %%
data = Data()

demand = data.get_demand()
waiting = data.get_waiting()
distances = data.get_distances()
crime = data.get_crime()

# %%
RADIUS = 2000
MAX_OFFICERS = 9

# %%
distances['in_range'] = (distances['distance'] <= RADIUS).astype(int)

# %%
distances['in_range'] = (distances['distance'] <= RADIUS).astype(int)
distances = distances.pivot(index='WPname',columns='DAuid',values='in_range')

# %%
distances = distances.loc[:, (distances.sum() > 0)]
distances.head()
# Out:
# DAuid                           59151910  59151913  59151914  59151915  \
# WPname
# APH Matthew Park                       0         0         0         0
# Aria Banquet Convention Center         0         0         0         0
# Bear Creek Park                        0         0         0         0
# Big plaza at 88 and scott road         0         0         0         0
# Bolivar Park                           1         1         1         1
#
# DAuid                           59151918  59151919  59151920  59151921  \
# WPname
# APH Matthew Park                       0         0         0         0
# Aria Banquet Convention Center         0         0         0         0
# Bear Creek Park                        0         0         0         0
# Big plaza at 88 and scott road         0         0         0         0
# Bolivar Park                           0         1         0         0
#
# DAuid                           59151922  59151923  ...  59153375  59153386  \
# WPname                                              ...
# APH Matthew Park                       0         0  ...         0         0
# Aria Banquet Convention Center         0         1  ...         0         0
# Bear Creek Park                        0         0  ...         1         0
# Big plaza at 88 and scott road         0         0  ...         0         0
# Bolivar Park                           1         0  ...         0         0
#
# DAuid                           59153388  59153455  59153535  59153563  \
# WPname
# APH Matthew Park                       1         0         1         0
# Aria Banquet Convention Center         0         0         0         0
# Bear Creek Park                        0         1         0         0
# Big plaza at 88 and scott road         0         0         0         0
# Bolivar Park                           0         0         0         0
#
# DAuid                           59153719  59153720  59153919  59153920
# WPname
# APH Matthew Park                       0         1         0         0
# Aria Banquet Convention Center         0         0         0         0
# Bear Creek Park                        1         0         1         1
# Big plaza at 88 and scott road         0         0         0         0
# Bolivar Park                           0         0         0         0
#
# [5 rows x 127 columns]

# %%
walleyDA = list(distances.columns)
demand = demand[demand['DAuid'].isin(walleyDA)]

# %%
coverage = {}
for index, row in distances.iterrows():
    coverage[index] = [set(row[row==1].keys())]

# %%
pop_dict = pd.Series(demand.population_val.values,index=demand.DAuid).to_dict()

# %%
demand
# Out:
#         DAuid  population_val  DAarea        lat         lon  FEDcode  \
# 56   59151910           555.0  0.2230  49.211293 -122.830840       32
# 59   59151913           462.0  2.3874  49.212635 -122.845019       32
# 60   59151914           528.0  0.2372  49.210042 -122.840417       32
# 61   59151915           639.0  0.2614  49.207381 -122.839230       32
# 64   59151918           591.0  0.2419  49.200283 -122.840601       32
# ..        ...             ...     ...        ...         ...      ...
# 545  59153563           473.0  0.0559  49.186924 -122.839187       32
# 556  59153719           514.0  0.1000  49.171313 -122.836222       32
# 557  59153720           511.0  0.7199  49.175867 -122.836148       32
# 604  59153919           818.0  0.1796  49.169438 -122.830393       32
# 605  59153920          1069.0  0.1540  49.166485 -122.829908       32
#
#                    FEDName
# 56   Surrey-Centre/Whalley
# 59   Surrey-Centre/Whalley
# 60   Surrey-Centre/Whalley
# 61   Surrey-Centre/Whalley
# 64   Surrey-Centre/Whalley
# ..                     ...
# 545  Surrey-Centre/Whalley
# 556  Surrey-Centre/Whalley
# 557  Surrey-Centre/Whalley
# 604  Surrey-Centre/Whalley
# 605  Surrey-Centre/Whalley
#
# [127 rows x 7 columns]

# %%
regions, population = gp.multidict(pop_dict)
waits, covered = gp.multidict(coverage)

# %%
m = gp.Model("SPMARP")
build = m.addVars(list(waiting['name']), vtype=GRB.BINARY, name="wait_points")
is_covered = m.addVars(list(distances.columns), vtype=GRB.BINARY, name="Is_covered")
# Out:
# Restricted license - for non-production use only - expires 2022-01-13

# %%
m.addConstrs((gp.quicksum(build[t] for t in waits if r in covered[t]) >= is_covered[r]
                        for r in regions), name="Build2cover")
# Out:
# {59151910: <gurobi.Constr *Awaiting Model Update*>,
#  59151913: <gurobi.Constr *Awaiting Model Update*>,
#  59151914: <gurobi.Constr *Awaiting Model Update*>,
#  59151915: <gurobi.Constr *Awaiting Model Update*>,
#  59151918: <gurobi.Constr *Awaiting Model Update*>,
#  59151919: <gurobi.Constr *Awaiting Model Update*>,
#  59151920: <gurobi.Constr *Awaiting Model Update*>,
#  59151921: <gurobi.Constr *Awaiting Model Update*>,
#  59151922: <gurobi.Constr *Awaiting Model Update*>,
#  59151923: <gurobi.Constr *Awaiting Model Update*>,
#  59151924: <gurobi.Constr *Awaiting Model Update*>,
#  59151925: <gurobi.Constr *Awaiting Model Update*>,
#  59151926: <gurobi.Constr *Awaiting Model Update*>,
#  59151927: <gurobi.Constr *Awaiting Model Update*>,
#  59151929: <gurobi.Constr *Awaiting Model Update*>,
#  59151931: <gurobi.Constr *Awaiting Model Update*>,
#  59151932: <gurobi.Constr *Awaiting Model Update*>,
#  59151933: <gurobi.Constr *Awaiting Model Update*>,
#  59151934: <gurobi.Constr *Awaiting Model Update*>,
#  59151942: <gurobi.Constr *Awaiting Model Update*>,
#  59151943: <gurobi.Constr *Awaiting Model Update*>,
#  59151945: <gurobi.Constr *Awaiting Model Update*>,
#  59151948: <gurobi.Constr *Awaiting Model Update*>,
#  59151949: <gurobi.Constr *Awaiting Model Update*>,
#  59151950: <gurobi.Constr *Awaiting Model Update*>,
#  59151951: <gurobi.Constr *Awaiting Model Update*>,
#  59151952: <gurobi.Constr *Awaiting Model Update*>,
#  59151955: <gurobi.Constr *Awaiting Model Update*>,
#  59151956: <gurobi.Constr *Awaiting Model Update*>,
#  59151957: <gurobi.Constr *Awaiting Model Update*>,
#  59151958: <gurobi.Constr *Awaiting Model Update*>,
#  59151959: <gurobi.Constr *Awaiting Model Update*>,
#  59151960: <gurobi.Constr *Awaiting Model Update*>,
#  59151961: <gurobi.Constr *Awaiting Model Update*>,
#  59151962: <gurobi.Constr *Awaiting Model Update*>,
#  59151963: <gurobi.Constr *Awaiting Model Update*>,
#  59151964: <gurobi.Constr *Awaiting Model Update*>,
#  59151965: <gurobi.Constr *Awaiting Model Update*>,
#  59151986: <gurobi.Constr *Awaiting Model Update*>,
#  59151992: <gurobi.Constr *Awaiting Model Update*>,
#  59151993: <gurobi.Constr *Awaiting Model Update*>,
#  59151995: <gurobi.Constr *Awaiting Model Update*>,
#  59151997: <gurobi.Constr *Awaiting Model Update*>,
#  59152105: <gurobi.Constr *Awaiting Model Update*>,
#  59152107: <gurobi.Constr *Awaiting Model Update*>,
#  59152171: <gurobi.Constr *Awaiting Model Update*>,
#  59152172: <gurobi.Constr *Awaiting Model Update*>,
#  59152173: <gurobi.Constr *Awaiting Model Update*>,
#  59152174: <gurobi.Constr *Awaiting Model Update*>,
#  59152175: <gurobi.Constr *Awaiting Model Update*>,
#  59152176: <gurobi.Constr *Awaiting Model Update*>,
#  59152177: <gurobi.Constr *Awaiting Model Update*>,
#  59152178: <gurobi.Constr *Awaiting Model Update*>,
#  59152179: <gurobi.Constr *Awaiting Model Update*>,
#  59152180: <gurobi.Constr *Awaiting Model Update*>,
#  59152181: <gurobi.Constr *Awaiting Model Update*>,
#  59152182: <gurobi.Constr *Awaiting Model Update*>,
#  59152183: <gurobi.Constr *Awaiting Model Update*>,
#  59152184: <gurobi.Constr *Awaiting Model Update*>,
#  59152185: <gurobi.Constr *Awaiting Model Update*>,
#  59152186: <gurobi.Constr *Awaiting Model Update*>,
#  59152187: <gurobi.Constr *Awaiting Model Update*>,
#  59152188: <gurobi.Constr *Awaiting Model Update*>,
#  59152189: <gurobi.Constr *Awaiting Model Update*>,
#  59152190: <gurobi.Constr *Awaiting Model Update*>,
#  59152191: <gurobi.Constr *Awaiting Model Update*>,
#  59152192: <gurobi.Constr *Awaiting Model Update*>,
#  59152193: <gurobi.Constr *Awaiting Model Update*>,
#  59152194: <gurobi.Constr *Awaiting Model Update*>,
#  59152195: <gurobi.Constr *Awaiting Model Update*>,
#  59152196: <gurobi.Constr *Awaiting Model Update*>,
#  59152197: <gurobi.Constr *Awaiting Model Update*>,
#  59152198: <gurobi.Constr *Awaiting Model Update*>,
#  59152199: <gurobi.Constr *Awaiting Model Update*>,
#  59152200: <gurobi.Constr *Awaiting Model Update*>,
#  59152201: <gurobi.Constr *Awaiting Model Update*>,
#  59152202: <gurobi.Constr *Awaiting Model Update*>,
#  59152203: <gurobi.Constr *Awaiting Model Update*>,
#  59152204: <gurobi.Constr *Awaiting Model Update*>,
#  59152205: <gurobi.Constr *Awaiting Model Update*>,
#  59152206: <gurobi.Constr *Awaiting Model Update*>,
#  59152207: <gurobi.Constr *Awaiting Model Update*>,
#  59152208: <gurobi.Constr *Awaiting Model Update*>,
#  59152209: <gurobi.Constr *Awaiting Model Update*>,
#  59152210: <gurobi.Constr *Awaiting Model Update*>,
#  59152211: <gurobi.Constr *Awaiting Model Update*>,
#  59152212: <gurobi.Constr *Awaiting Model Update*>,
#  59152213: <gurobi.Constr *Awaiting Model Update*>,
#  59152214: <gurobi.Constr *Awaiting Model Update*>,
#  59152217: <gurobi.Constr *Awaiting Model Update*>,
#  59152218: <gurobi.Constr *Awaiting Model Update*>,
#  59152219: <gurobi.Constr *Awaiting Model Update*>,
#  59152220: <gurobi.Constr *Awaiting Model Update*>,
#  59152221: <gurobi.Constr *Awaiting Model Update*>,
#  59152222: <gurobi.Constr *Awaiting Model Update*>,
#  59152223: <gurobi.Constr *Awaiting Model Update*>,
#  59152224: <gurobi.Constr *Awaiting Model Update*>,
#  59152225: <gurobi.Constr *Awaiting Model Update*>,
#  59152226: <gurobi.Constr *Awaiting Model Update*>,
#  59152227: <gurobi.Constr *Awaiting Model Update*>,
#  59152228: <gurobi.Constr *Awaiting Model Update*>,
#  59152229: <gurobi.Constr *Awaiting Model Update*>,
#  59152230: <gurobi.Constr *Awaiting Model Update*>,
#  59152231: <gurobi.Constr *Awaiting Model Update*>,
#  59152232: <gurobi.Constr *Awaiting Model Update*>,
#  59152233: <gurobi.Constr *Awaiting Model Update*>,
#  59152234: <gurobi.Constr *Awaiting Model Update*>,
#  59152235: <gurobi.Constr *Awaiting Model Update*>,
#  59152236: <gurobi.Constr *Awaiting Model Update*>,
#  59152237: <gurobi.Constr *Awaiting Model Update*>,
#  59152238: <gurobi.Constr *Awaiting Model Update*>,
#  59152239: <gurobi.Constr *Awaiting Model Update*>,
#  59152964: <gurobi.Constr *Awaiting Model Update*>,
#  59152965: <gurobi.Constr *Awaiting Model Update*>,
#  59152966: <gurobi.Constr *Awaiting Model Update*>,
#  59152967: <gurobi.Constr *Awaiting Model Update*>,
#  59153367: <gurobi.Constr *Awaiting Model Update*>,
#  59153375: <gurobi.Constr *Awaiting Model Update*>,
#  59153386: <gurobi.Constr *Awaiting Model Update*>,
#  59153388: <gurobi.Constr *Awaiting Model Update*>,
#  59153455: <gurobi.Constr *Awaiting Model Update*>,
#  59153535: <gurobi.Constr *Awaiting Model Update*>,
#  59153563: <gurobi.Constr *Awaiting Model Update*>,
#  59153719: <gurobi.Constr *Awaiting Model Update*>,
#  59153720: <gurobi.Constr *Awaiting Model Update*>,
#  59153919: <gurobi.Constr *Awaiting Model Update*>,
#  59153920: <gurobi.Constr *Awaiting Model Update*>}

# %%
m.addConstr(gp.quicksum(build[t] for t in waits) == MAX_OFFICERS, name="officers")
# Out:
# <gurobi.Constr *Awaiting Model Update*>

# %%
m.setObjective(is_covered.prod(population), GRB.MAXIMIZE)

# %%
m.optimize()
# Out:
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 128 rows, 146 columns and 487 nonzeros
# Model fingerprint: 0x40c5b735
# Variable types: 0 continuous, 146 integer (146 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e+02, 2e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [9e+00, 9e+00]
# Found heuristic solution: objective 78402.000000
# Presolve removed 72 rows and 72 columns
# Presolve time: 0.00s
# Presolved: 56 rows, 74 columns, 275 nonzeros
# Variable types: 0 continuous, 74 integer (74 binary)
#
# Root relaxation: objective 9.890400e+04, 7 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    98904.000000 98904.0000  0.00%     -    0s
#
# Explored 0 nodes (7 simplex iterations) in 0.04 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 98904 78402
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.890400000000e+04, best bound 9.890400000000e+04, gap 0.0000%

# %%
for tower in build.keys():
    if (abs(build[tower].x) > 1e-6):
        print(f"\n Place officer at location {tower}.")
# Out:
#  Place officer at location Bear Creek Park.
#
#  Place officer at location Big plaza at 88 and scott road.
#
#  Place officer at location LA Matheson Secondary School/Moffat Park.
#
#  Place officer at location Aria Banquet Convention Center.
#
#  Place officer at location Bolivar Park.
#
#  Place officer at location David Brankin Elementary School/William Beagle Park.
#
#  Place officer at location Kwantlen Park.
#
#  Place officer at location King George Skytrain.
#
#  Place officer at location Surrey Central.

# %%
total_population = 0

for region in regions:
    total_population += population[region]

percent = round(100*m.objVal/total_population, 2)

print(f"\n The population coverage associated to the patrol officer distribution is: {percent} %")
# Out:
#  The population coverage associated to the patrol officer distribution is: 99.28 %
