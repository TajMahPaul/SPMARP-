# %%
from db.data import Data
import pandas as pd
import os

# set data class as global
data = Data()
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

import googlemaps
from math import cos, sin, asin, sqrt, pi, atan2, radians

# %%
df_demand = data.get_demand()

# %%
df_crime = pd.read_csv('crime_2020.csv')

# %%
df_crime['HUNDRED_BLOCK'] = df_crime['HUNDRED_BLOCK'] + ' Surrey, BC'

# %%
df_crime
# Out:
#                     INCIDENT_TYPE                     HUNDRED_BLOCK  MONTH  \
# 0      Break and Enter - Business         11000 124TH ST Surrey, BC      1
# 1      Break and Enter - Business        13900 104TH AVE Surrey, BC      1
# 2      Break and Enter - Business         11100 SCOTT RD Surrey, BC      1
# 3      Break and Enter - Business    10500 UNIVERSITY DR Surrey, BC      1
# 4      Break and Enter - Business         10400 138TH ST Surrey, BC      1
# ...                           ...                               ...    ...
# 16742      Fatal/Injury Collision    152ND ST / 20TH AVE Surrey, BC     12
# 16743      Fatal/Injury Collision          2200 160TH ST Surrey, BC     12
# 16744      Fatal/Injury Collision         13900 16TH AVE Surrey, BC     12
# 16745      Fatal/Injury Collision  1700 KING GEORGE BLVD Surrey, BC     12
# 16746      Fatal/Injury Collision    152ND ST / 24TH AVE Surrey, BC     11
#
#        YEAR FILE_NUMBER
# 0      2020      20-680
# ...

# %%
key = "AIzaSyApefMuRG57ImJYcHR0gDFzGXecDBL-iDw"
gmaps = googlemaps.Client(key=key)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-519cfa60963c> in <module>
#       1 key = "AIzaSyApefMuRG57ImJYcHR0gDFzGXecDBL-iDw"
# ----> 2 gmaps = googlemaps.Client(key=key)
#
# NameError: name 'googlemaps' is not defined

# %%
one_crime
# Out:
# INCIDENT_TYPE    Break and Enter - Business
# HUNDRED_BLOCK     11000 124TH ST Surrey, BC
# MONTH                                     1
# YEAR                                   2020
# FILE_NUMBER                          20-680
# Name: 0, dtype: object

# %%
one_crime = df_crime.loc[0]

# %%
one_crime.HUNDRED_BLOCK
# Out:
# '12900 115TH AVE Surrey, BC'

# %%
import googlemaps
key = "AIzaSyApefMuRG57ImJYcHR0gDFzGXecDBL-iDw"
gmaps = googlemaps.Client(key=key)
geocode_result = gmaps.geocode(PUT ADDRESS HERE)

# %%
res_dict = {}

# %%
geocode_result
# Out:
# [{'address_components': [{'long_name': '11000',
#     'short_name': '11000',
#     'types': ['street_number']},
#    {'long_name': '124 Street', 'short_name': '124 St', 'types': ['route']},
#    {'long_name': 'South Westminster',
#     'short_name': 'South Westminster',
#     'types': ['neighborhood', 'political']},
#    {'long_name': 'Surrey',
#     'short_name': 'Surrey',
#     'types': ['locality', 'political']},
#    {'long_name': 'Metro Vancouver',
#     'short_name': 'Metro Vancouver',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'British Columbia',
#     'short_name': 'BC',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'Canada',
#     'short_name': 'CA',
#     'types': ['country', 'political']},
#    {'long_name': 'V3V 4T9',
#     'short_name': 'V3V 4T9',
#     'types': ['postal_code']}],
#   'formatted_address': '11000 124 St, Surrey, BC V3V 4T9, Canada',
# ...

# %%
res_dict[one_crime.FILE_NUMBER] = geocode_result

# %%
res_dict
# Out:
# {'20-680': [{'address_components': [{'long_name': '11000',
#      'short_name': '11000',
#      'types': ['street_number']},
#     {'long_name': '124 Street', 'short_name': '124 St', 'types': ['route']},
#     {'long_name': 'South Westminster',
#      'short_name': 'South Westminster',
#      'types': ['neighborhood', 'political']},
#     {'long_name': 'Surrey',
#      'short_name': 'Surrey',
#      'types': ['locality', 'political']},
#     {'long_name': 'Metro Vancouver',
#      'short_name': 'Metro Vancouver',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'British Columbia',
#      'short_name': 'BC',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'Canada',
#      'short_name': 'CA',
#      'types': ['country', 'political']},
#     {'long_name': 'V3V 4T9',
#      'short_name': 'V3V 4T9',
#      'types': ['postal_code']}],
#    'formatted_address': '11000 124 St, Surrey, BC V3V 4T9, Canada',
# ...

# %%
res_dict[one_crime.FILE_NUMBER]
# Out:
# [{'address_components': [{'long_name': '11000',
#     'short_name': '11000',
#     'types': ['street_number']},
#    {'long_name': '124 Street', 'short_name': '124 St', 'types': ['route']},
#    {'long_name': 'South Westminster',
#     'short_name': 'South Westminster',
#     'types': ['neighborhood', 'political']},
#    {'long_name': 'Surrey',
#     'short_name': 'Surrey',
#     'types': ['locality', 'political']},
#    {'long_name': 'Metro Vancouver',
#     'short_name': 'Metro Vancouver',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'British Columbia',
#     'short_name': 'BC',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'Canada',
#     'short_name': 'CA',
#     'types': ['country', 'political']},
#    {'long_name': 'V3V 4T9',
#     'short_name': 'V3V 4T9',
#     'types': ['postal_code']}],
#   'formatted_address': '11000 124 St, Surrey, BC V3V 4T9, Canada',
# ...

# %%
latlng = geocode_result[0]['geometry']['location']
latlng
# Out:
# {'lat': 49.20219669999999, 'lng': -122.878468}

# %%
lat = latlng['lat']
lng = latlng['lng']

# %%
test = df_demand.iloc[57]
test
# Out:
# DAuid                          59151911
# population_val                      798
# DAarea                           0.7084
# lat                             49.2096
# lon                            -122.822
# FEDcode                              32
# FEDName           Surrey-Centre/Whalley
# Name: 57, dtype: object

# %%
def hav_distance(lat1, lon1, lat2, lon2):
        #Taken from https://stackoverflow.com/a/4913653
        """
        Calculate the great circle distance between two points 
        on the earth (specified in decimal degrees)
        """
        # convert decimal degrees to radians 
        lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])

        # haversine formula 
        dlon = lon2 - lon1 
        dlat = lat2 - lat1 
        a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
        c = 2 * asin(sqrt(a)) 
        r = 63710 # Radius of earth in km
        return c * r

# %%
df_demand
# Out:
#         DAuid  population_val  DAarea        lat         lon  FEDcode  \
# 0    59151838           941.0  2.5917  49.187082 -122.740379       12
# 1    59151839           303.0  2.7945  49.169710 -122.745703       12
# 2    59151840           801.0  0.7341  49.173207 -122.765197       12
# 3    59151841           731.0  0.2013  49.175556 -122.772461       12
# 4    59151842           881.0  0.3040  49.172899 -122.775759       12
# ..        ...             ...     ...        ...         ...      ...
# 626  59154021          3401.0  0.6632  49.129477 -122.684232        7
# 627  59154022          1106.0  0.6597  49.056512 -122.773848       30
# 628  59154023           262.0  0.9200  49.053780 -122.762388       30
# 629  59154024          3702.0  0.7317  49.048718 -122.774447       30
# 630  59154025           907.0  1.7287  49.039875 -122.771762       30
#
#                      FEDName
# 0       Fleetwood/Port Kells
# 1       Fleetwood/Port Kells
# 2       Fleetwood/Port Kells
# ...

# %%
hav_distance(test.lat,test.lon, lat, lng)
# Out:
# 42.105445391317474

# %%
df_demand['distance'] = df_demand.apply(lambda x: hav_distance(x['lat'],x['lon'],lat,lng), axis=1)

# %%
df_demand
# Out:
#         DAuid  population_val  DAarea        lat         lon  FEDcode  \
# 0    59151838           941.0  2.5917  49.187082 -122.740379       12
# 1    59151839           303.0  2.7945  49.169710 -122.745703       12
# 2    59151840           801.0  0.7341  49.173207 -122.765197       12
# 3    59151841           731.0  0.2013  49.175556 -122.772461       12
# 4    59151842           881.0  0.3040  49.172899 -122.775759       12
# ..        ...             ...     ...        ...         ...      ...
# 626  59154021          3401.0  0.6632  49.129477 -122.684232        7
# 627  59154022          1106.0  0.6597  49.056512 -122.773848       30
# 628  59154023           262.0  0.9200  49.053780 -122.762388       30
# 629  59154024          3702.0  0.7317  49.048718 -122.774447       30
# 630  59154025           907.0  1.7287  49.039875 -122.771762       30
#
#                      FEDName    distance
# 0       Fleetwood/Port Kells  101.740048
# 1       Fleetwood/Port Kells  103.030731
# ...

# %%
df_demand.loc[df_demand['distance'].idxmin()]
# Out:
# DAuid                          59152965
# population_val                      665
# DAarea                           0.4291
# lat                              49.211
# lon                            -122.868
# FEDcode                              32
# FEDName           Surrey-Centre/Whalley
# distance                        3.95958
# Name: 491, dtype: object

# %%
df_crime['new'], df_crime['new2'] = 'hey', 'hey2'

# %%
df_crime
# Out:
#                     INCIDENT_TYPE                     HUNDRED_BLOCK  MONTH  \
# 0      Break and Enter - Business         11000 124TH ST Surrey, BC      1
# 1      Break and Enter - Business        13900 104TH AVE Surrey, BC      1
# 2      Break and Enter - Business         11100 SCOTT RD Surrey, BC      1
# 3      Break and Enter - Business    10500 UNIVERSITY DR Surrey, BC      1
# 4      Break and Enter - Business         10400 138TH ST Surrey, BC      1
# ...                           ...                               ...    ...
# 16742      Fatal/Injury Collision    152ND ST / 20TH AVE Surrey, BC     12
# 16743      Fatal/Injury Collision          2200 160TH ST Surrey, BC     12
# 16744      Fatal/Injury Collision         13900 16TH AVE Surrey, BC     12
# 16745      Fatal/Injury Collision  1700 KING GEORGE BLVD Surrey, BC     12
# 16746      Fatal/Injury Collision    152ND ST / 24TH AVE Surrey, BC     11
#
#        YEAR FILE_NUMBER  new  new2
# ...
